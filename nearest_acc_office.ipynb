# %%
# !pip install geoviews
# !pip install --upgrade hvplot holoviews
# Out:
# Requirement already satisfied: geoviews in c:\anaconda\lib\site-packages (1.12.0)
# Requirement already satisfied: bokeh<3.5.0,>=3.4.0 in c:\anaconda\lib\site-packages (from geoviews) (3.4.3)
# Requirement already satisfied: cartopy>=0.18.0 in c:\anaconda\lib\site-packages (from geoviews) (0.23.0)
# Requirement already satisfied: holoviews>=1.16.0 in c:\anaconda\lib\site-packages (from geoviews) (1.20.0)
# Requirement already satisfied: packaging in c:\anaconda\lib\site-packages (from geoviews) (23.1)
# Requirement already satisfied: numpy in c:\anaconda\lib\site-packages (from geoviews) (1.26.4)
# Requirement already satisfied: shapely in c:\anaconda\lib\site-packages (from geoviews) (2.0.5)
# Requirement already satisfied: param in c:\anaconda\lib\site-packages (from geoviews) (2.1.1)
# Requirement already satisfied: panel>=1.0.0 in c:\anaconda\lib\site-packages (from geoviews) (1.4.4)
# Requirement already satisfied: pyproj in c:\anaconda\lib\site-packages (from geoviews) (3.6.1)
# Requirement already satisfied: xyzservices in c:\anaconda\lib\site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\anaconda\lib\site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (3.1.3)
# Requirement already satisfied: contourpy>=1.2 in c:\anaconda\lib\site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (1.2.0)
# Requirement already satisfied: pandas>=1.2 in c:\anaconda\lib\site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (2.1.4)
# Requirement already satisfied: pillow>=7.1.0 in c:\anaconda\lib\site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (10.2.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\김동규\appdata\roaming\python\python311\site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\김동규\appdata\roaming\python\python311\site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (6.3.3)
# Requirement already satisfied: matplotlib>=3.5 in c:\anaconda\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.8.0)
# Requirement already satisfied: pyshp>=2.3 in c:\anaconda\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: colorcet in c:\anaconda\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.1)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\anaconda\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.0)
# Requirement already satisfied: markdown in c:\anaconda\lib\site-packages (from panel>=1.0.0->geoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\anaconda\lib\site-packages (from panel>=1.0.0->geoviews) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\anaconda\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\anaconda\lib\site-packages (from panel>=1.0.0->geoviews) (0.3.0)
# Requirement already satisfied: requests in c:\anaconda\lib\site-packages (from panel>=1.0.0->geoviews) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\anaconda\lib\site-packages (from panel>=1.0.0->geoviews) (4.65.0)
# Requirement already satisfied: bleach in c:\users\김동규\appdata\roaming\python\python311\site-packages (from panel>=1.0.0->geoviews) (6.1.0)
# Requirement already satisfied: typing-extensions in c:\anaconda\lib\site-packages (from panel>=1.0.0->geoviews) (4.9.0)
# Requirement already satisfied: certifi in c:\anaconda\lib\site-packages (from pyproj->geoviews) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda\lib\site-packages (from Jinja2>=2.9->bokeh<3.5.0,>=3.4.0->geoviews) (2.1.3)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\anaconda\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\anaconda\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anaconda\lib\site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\lib\site-packages (from pandas>=1.2->bokeh<3.5.0,>=3.4.0->geoviews) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\anaconda\lib\site-packages (from pandas>=1.2->bokeh<3.5.0,>=3.4.0->geoviews) (2023.3)
# Requirement already satisfied: colorama in c:\users\김동규\appdata\roaming\python\python311\site-packages (from tqdm>=4.48.0->panel>=1.0.0->geoviews) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in c:\anaconda\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\김동규\appdata\roaming\python\python311\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\anaconda\lib\site-packages (from colorcet->holoviews>=1.16.0->geoviews) (0.5.0)
# Requirement already satisfied: uc-micro-py in c:\anaconda\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\anaconda\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.0.7)
# Requirement already satisfied: hvplot in c:\anaconda\lib\site-packages (0.11.2)
# Requirement already satisfied: holoviews in c:\anaconda\lib\site-packages (1.20.0)
# Requirement already satisfied: bokeh>=3.1 in c:\anaconda\lib\site-packages (from hvplot) (3.4.3)
# Requirement already satisfied: colorcet>=2 in c:\anaconda\lib\site-packages (from hvplot) (3.0.1)
# Requirement already satisfied: numpy>=1.21 in c:\anaconda\lib\site-packages (from hvplot) (1.26.4)
# Requirement already satisfied: packaging in c:\anaconda\lib\site-packages (from hvplot) (23.1)
# Requirement already satisfied: pandas>=1.3 in c:\anaconda\lib\site-packages (from hvplot) (2.1.4)
# Requirement already satisfied: panel>=1.0 in c:\anaconda\lib\site-packages (from hvplot) (1.4.4)
# Requirement already satisfied: param<3.0,>=1.12.0 in c:\anaconda\lib\site-packages (from hvplot) (2.1.1)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\anaconda\lib\site-packages (from holoviews) (3.0.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\anaconda\lib\site-packages (from bokeh>=3.1->hvplot) (3.1.3)
# Requirement already satisfied: contourpy>=1.2 in c:\anaconda\lib\site-packages (from bokeh>=3.1->hvplot) (1.2.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\anaconda\lib\site-packages (from bokeh>=3.1->hvplot) (10.2.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\김동규\appdata\roaming\python\python311\site-packages (from bokeh>=3.1->hvplot) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\김동규\appdata\roaming\python\python311\site-packages (from bokeh>=3.1->hvplot) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\anaconda\lib\site-packages (from bokeh>=3.1->hvplot) (2022.9.0)
# Requirement already satisfied: pyct>=0.4.4 in c:\anaconda\lib\site-packages (from colorcet>=2->hvplot) (0.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\anaconda\lib\site-packages (from pandas>=1.3->hvplot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\lib\site-packages (from pandas>=1.3->hvplot) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\anaconda\lib\site-packages (from pandas>=1.3->hvplot) (2023.3)
# Requirement already satisfied: markdown in c:\anaconda\lib\site-packages (from panel>=1.0->hvplot) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\anaconda\lib\site-packages (from panel>=1.0->hvplot) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\anaconda\lib\site-packages (from panel>=1.0->hvplot) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\anaconda\lib\site-packages (from panel>=1.0->hvplot) (0.3.0)
# Requirement already satisfied: requests in c:\anaconda\lib\site-packages (from panel>=1.0->hvplot) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\anaconda\lib\site-packages (from panel>=1.0->hvplot) (4.65.0)
# Requirement already satisfied: bleach in c:\users\김동규\appdata\roaming\python\python311\site-packages (from panel>=1.0->hvplot) (6.1.0)
# Requirement already satisfied: typing-extensions in c:\anaconda\lib\site-packages (from panel>=1.0->hvplot) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda\lib\site-packages (from Jinja2>=2.9->bokeh>=3.1->hvplot) (2.1.3)
# Requirement already satisfied: six>=1.5 in c:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3->hvplot) (1.16.0)
# Requirement already satisfied: colorama in c:\users\김동규\appdata\roaming\python\python311\site-packages (from tqdm>=4.48.0->panel>=1.0->hvplot) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\김동규\appdata\roaming\python\python311\site-packages (from bleach->panel>=1.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\anaconda\lib\site-packages (from linkify-it-py->panel>=1.0->hvplot) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\anaconda\lib\site-packages (from markdown-it-py->panel>=1.0->hvplot) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\lib\site-packages (from requests->panel>=1.0->hvplot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests->panel>=1.0->hvplot) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\lib\site-packages (from requests->panel>=1.0->hvplot) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests->panel>=1.0->hvplot) (2024.2.2)

# %%
import json
import requests
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
from pathlib import Path
from config import geoapifi_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='d64a0aaa-2b7f-42ef-8e10-35f30d97a3db'>
#   <div id="d1167ef1-db0a-4ad1-be47-973ba9a5b40f" data-root-id="d64a0aaa-2b7f-42ef-8e10-35f30d97a3db" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"fad2563b-990d-4148-a997-11c6873ae65a":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"d64a0aaa-2b7f-42ef-8e10-35f30d97a3db"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"b20600af-35e1-4ee9-88fd-6ee46ef75e6e","attributes":{"plot_id":"d64a0aaa-2b7f-42ef-8e10-35f30d97a3db","comm_id":"37515e3663b3480a96849529b9c08c15","client_comm_id":"d40a03e3ae604371a6ca937d5b957cbe"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"fad2563b-990d-4148-a997-11c6873ae65a","roots":{"d64a0aaa-2b7f-42ef-8e10-35f30d97a3db":"d1167ef1-db0a-4ad1-be47-973ba9a5b40f"},"root_ids":["d64a0aaa-2b7f-42ef-8e10-35f30d97a3db"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# # Get the Longtitude and Latitude of Tower Palace

# %%
# set the base URL for Geocoding API
base_url = "https://api.geoapify.com/v1/geocode/search?"

# set the request parameters for Tower Palace
country = "Korea"
name = "Tower Palace"
city = "Seoul"
postcode = "06293"
format = "json"

# create a parameter dictionary 
params = {
    "apiKey": geoapifi_key,
    "format": format,
    "country": country,
    "city": city,
    "postcode": postcode,
    "name": name
}

# request the URL and convert the json data type into python data type
response = requests.get(base_url, params = params).json()
print(json.dumps(response, indent = 4, sort_keys = True))
# Out:
# {
#     "query": {
#         "city": "Seoul",
#         "country": "Korea",
#         "parsed": {
#             "city": "Seoul",
#             "country": "Korea",
#             "expected_type": "amenity",
#             "house": "Tower Palace",
#             "postcode": "06293"
#         },
#         "postcode": "06293",
#         "text": ""
#     },
#     "results": [
#         {
#             "address_line1": "Tower Palace",
#             "address_line2": "Nambusunhwan-ro, Dogok 2(i)-dong, Seoul, 06293, South Korea",
#             "bbox": {
#                 "lat1": 37.4896886,
#                 "lat2": 37.4897886,
#                 "lon1": 127.053188,
#                 "lon2": 127.053288
#             },
#             "category": "public_transport.bus",
#             "city": "Seoul",
#             "country": "South Korea",
#             "country_code": "kr",
#             "datasource": {
#                 "attribution": "\u00a9 OpenStreetMap contributors",
#                 "license": "Open Database License",
#                 "sourcename": "openstreetmap",
#                 "url": "https://www.openstreetmap.org/copyright"
#             },
#             "district": "Gangnam-gu",
#             "formatted": "Tower Palace, Nambusunhwan-ro, Dogok 2(i)-dong, Seoul, 06293, South Korea",
#             "lat": 37.4897386,
#             "lon": 127.053238,
#             "name": "Tower Palace",
#             "place_id": "51e2395b4068c35f40595f4b23c1afbe4240f00103f901b23d2f4d02000000c0020192030c546f7765722050616c616365",
#             "plus_code": "8Q99F3Q3+V7",
#             "plus_code_short": "F3Q3+V7 Seoul, South Korea",
#             "postcode": "06293",
#             "rank": {
#                 "confidence": 0,
#                 "confidence_city_level": 0,
#                 "importance": 0.5200099999999999,
#                 "match_type": "full_match",
#                 "popularity": 4.0301259553307185
#             },
#             "ref": "23829",
#             "result_type": "amenity",
#             "street": "Nambusunhwan-ro",
#             "suburb": "Dogok 2(i)-dong",
#             "timezone": {
#                 "abbreviation_DST": "KST",
#                 "abbreviation_STD": "KST",
#                 "name": "Asia/Seoul",
#                 "offset_DST": "+09:00",
#                 "offset_DST_seconds": 32400,
#                 "offset_STD": "+09:00",
#                 "offset_STD_seconds": 32400
#             }
#         }
#     ]
# }

# %%
# get the latitude and longtitude data of Tower Palace
latitude = response["results"][0]["lat"]
longtitude = response["results"][0]["lon"]
print(f"The latitude and longtitude of Tower Palace is {latitude} and {longtitude} each.")
# Out:
# The latitude and longtitude of Tower Palace is 37.4897386 and 127.053238 each.

# %% [markdown]
# # Get the list of 5 Nearest Accountant Offices to Tower Palace

# %%
# set a base URL for places API
base_url = "https://api.geoapify.com/v2/places?"

# set the request parameters for nearest accountant offices to Tower Palace
format = "json"
categories = "office.accountant"
filter = f"circle:{longtitude},{latitude},50000"
bias = f"proximity:{longtitude},{latitude}"

# create a parameter dictionary
params = {
    "apiKey": geoapifi_key,
    "format": format,
    "categories": categories,
    "filter": filter,
    "bias": bias,
    "limit": 30
}

# request the URl based on the parameters and convert json data type to the python data type
response = requests.get(base_url, params = params).json()
print(json.dumps(response, indent = 4, sort_keys = True, ensure_ascii = False))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     127.10388680000001,
#                     37.516478299915356
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "세무사김창식사무소",
#                 "address_line2": "11 Olympic-ro 35ga-gil, Jamsil 6(yuk)-dong, Seoul, 05504, South Korea",
#                 "categories": [
#                     "office",
#                     "office.accountant"
#                 ],
#                 "city": "Seoul",
#                 "country": "South Korea",
#                 "country_code": "kr",
#                 "datasource": {
#                     "attribution": "© OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "raw": {
#                         "addr:city": "송파구",
#                         "addr:housenumber": 11,
#                         "addr:street": "올림픽로35가길",
#                         "name": "세무사김창식사무소",
#                         "office": "accountant",
#                         "osm_id": 4636445867,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 5373,
#                 "district": "Songpa-gu",
#                 "formatted": "세무사김창식사무소, 11 Olympic-ro 35ga-gil, Jamsil 6(yuk)-dong, Seoul, 05504, South Korea",
#                 "housenumber": "11",
#                 "lat": 37.5164783,
#                 "lon": 127.1038868,
#                 "name": "세무사김창식사무소",
#                 "place_id": "511d1fd214a6c65f4059759dfff51bc24240f00103f901ab8c5a140100000092031bec84b8ebacb4ec82aceab980ecb0bdec8b9dec82acebacb4ec868c",
#                 "postcode": "05504",
#                 "quarter": "Sincheon-dong",
#                 "street": "Olympic-ro 35ga-gil",
#                 "suburb": "Jamsil 6(yuk)-dong"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     127.07541819999997,
#                     37.55835339992099
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "삼정세무회계사무소",
#                 "address_line2": "512 Cheonho-daero, Gunja-dong, Seoul, 05000, South Korea",
#                 "categories": [
#                     "office",
#                     "office.accountant"
#                 ],
#                 "city": "Seoul",
#                 "country": "South Korea",
#                 "country_code": "kr",
#                 "datasource": {
#                     "attribution": "© OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "raw": {
#                         "addr:city": "서울시 광진구",
#                         "addr:housenumber": 512,
#                         "addr:street": "천호대로",
#                         "name": "삼정세무회계사무소",
#                         "office": "accountant",
#                         "osm_id": 10247209072,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 7864,
#                 "district": "Gwangjin-gu",
#                 "formatted": "삼정세무회계사무소, 512 Cheonho-daero, Gunja-dong, Seoul, 05000, South Korea",
#                 "housenumber": "512",
#                 "lat": 37.5583534,
#                 "lon": 127.0754182,
#                 "name": "삼정세무회계사무소",
#                 "place_id": "517aa1dba6d3c45f4059b222cc1f78c74240f00103f9017000c8620200000092031bec82bceca095ec84b8ebacb4ed9a8ceab384ec82acebacb4ec868c",
#                 "postcode": "05000",
#                 "street": "Cheonho-daero",
#                 "suburb": "Gunja-dong"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     126.96405869251558,
#                     37.56380034992172
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "한국공인회계사회",
#                 "address_line2": "Chungjeong-ro 7-gil, Chunghyeon-dong, Seoul, 03742, South Korea",
#                 "categories": [
#                     "building",
#                     "building.office",
#                     "office",
#                     "office.accountant"
#                 ],
#                 "city": "Seoul",
#                 "country": "South Korea",
#                 "country_code": "kr",
#                 "datasource": {
#                     "attribution": "© OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "raw": {
#                         "building": "yes",
#                         "name": "한국공인회계사회",
#                         "office": "accountant",
#                         "osm_id": 854278902,
#                         "osm_type": "w"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 11370,
#                 "district": "Seodaemun-gu",
#                 "formatted": "한국공인회계사회, Chungjeong-ro 7-gil, Chunghyeon-dong, Seoul, 03742, South Korea",
#                 "lat": 37.56380035,
#                 "lon": 126.96405869251558,
#                 "name": "한국공인회계사회",
#                 "place_id": "51daf13a23b3bd5f40598e31209c2ac84240f00102f901f642eb3200000000920318ed959ceab5adeab3b5ec9db8ed9a8ceab384ec82aced9a8c",
#                 "postcode": "03742",
#                 "quarter": "Chungjeongno 2-ga",
#                 "street": "Chungjeong-ro 7-gil",
#                 "suburb": "Chunghyeon-dong"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     127.06423050000001,
#                     37.61388069992852
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "신우세무회계사무소",
#                 "address_line2": "36 Hwarang-ro 42-gil, Seokgwan-dong, Seoul, 02781, South Korea",
#                 "categories": [
#                     "office",
#                     "office.accountant"
#                 ],
#                 "city": "Seoul",
#                 "country": "South Korea",
#                 "country_code": "kr",
#                 "datasource": {
#                     "attribution": "© OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "raw": {
#                         "addr:city": "서울 성북구",
#                         "addr:housenumber": 36,
#                         "addr:street": "화랑로42길",
#                         "name": "신우세무회계사무소",
#                         "office": "accountant",
#                         "osm_id": 11042977756,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 13812,
#                 "district": "Seongbuk-gu",
#                 "formatted": "신우세무회계사무소, 36 Hwarang-ro 42-gil, Seokgwan-dong, Seoul, 02781, South Korea",
#                 "housenumber": "36",
#                 "lat": 37.6138807,
#                 "lon": 127.0642305,
#                 "name": "신우세무회계사무소",
#                 "place_id": "51f8393e5a1cc45f405957eb8ca493ce4240f00103f901dc7736920200000092031bec8ba0ec9ab0ec84b8ebacb4ed9a8ceab384ec82acebacb4ec868c",
#                 "postcode": "02781",
#                 "street": "Hwarang-ro 42-gil",
#                 "suburb": "Seokgwan-dong"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     126.95647959999998,
#                     37.346181299892706
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Songseol Accountant",
#                 "address_line2": "30 Gosan-ro 151beon-gil, Gunpo-si, 15853, South Korea",
#                 "categories": [
#                     "office",
#                     "office.accountant"
#                 ],
#                 "city": "Gunpo-si",
#                 "contact": {
#                     "phone": "+82 31 477 1501"
#                 },
#                 "country": "South Korea",
#                 "country_code": "kr",
#                 "county": "Gyeonggi",
#                 "datasource": {
#                     "attribution": "© OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "raw": {
#                         "addr:city": "군포시",
#                         "addr:housenumber": 30,
#                         "addr:postcode": 15853,
#                         "addr:street": "고산로151번길",
#                         "level": 4,
#                         "name": "송설세무회계컨설팅",
#                         "name:en": "Songseol Accountant",
#                         "name:ko": "송설세무회계컨설팅",
#                         "office": "accountant",
#                         "opening_hours": "Mo-Fr 09:00-18:00",
#                         "osm_id": 10709274181,
#                         "osm_type": "n",
#                         "phone": "+82 31 477 1501",
#                         "website": "http://www.etax365.net/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "distance": 18089,
#                 "district": "Gunpo 1-dong",
#                 "formatted": "Songseol Accountant, 30 Gosan-ro 151beon-gil, Gunpo-si, 15853, South Korea",
#                 "housenumber": "30",
#                 "lat": 37.3461813,
#                 "lon": 126.9564796,
#                 "name": "송설세무회계컨설팅",
#                 "name_international": {
#                     "en": "Songseol Accountant",
#                     "ko": "송설세무회계컨설팅"
#                 },
#                 "opening_hours": "Mo-Fr 09:00-18:00",
#                 "place_id": "51a15236f636bd5f405952c338ab4fac4240f00103f901458e527e0200000092031bec86a1ec84a4ec84b8ebacb4ed9a8ceab384ecbba8ec84a4ed8c85",
#                 "postcode": "15853",
#                 "street": "Gosan-ro 151beon-gil",
#                 "website": "http://www.etax365.net/"
#             },
#             "type": "Feature"
#         }
#     ],
#     "type": "FeatureCollection"
# }

# %%
# create lists for accountant office information
name = []
address = []
lat = []
lon = []

# create a dictionary
info_dic = {
    "Name": name,
    "Address": address,
    "Latitude": lat,
    "Longtitude": lon
}

# get the 5 nearest accountant offices to Tower Palace
for acc_office in response["features"]:

    office_name = acc_office["properties"]["name"]
    office_address = acc_office["properties"]["address_line2"]
    office_lat = acc_office["properties"]["lat"]
    office_lon = acc_office["properties"]["lon"]

    name.append(office_name)
    address.append(office_address)
    lat.append(office_lat)
    lon.append(office_lon)

# create a dataframe of accountant offices
acc_office_df = pd.DataFrame(
    data = info_dic
)

acc_office_df
# Out:
#         Name                                            Address   Latitude  \
# 0  세무사김창식사무소  11 Olympic-ro 35ga-gil, Jamsil 6(yuk)-dong, Se...  37.516478
# 1  삼정세무회계사무소  512 Cheonho-daero, Gunja-dong, Seoul, 05000, S...  37.558353
# 2   한국공인회계사회  Chungjeong-ro 7-gil, Chunghyeon-dong, Seoul, 0...  37.563800
# 3  신우세무회계사무소  36 Hwarang-ro 42-gil, Seokgwan-dong, Seoul, 02...  37.613881
# 4  송설세무회계컨설팅  30 Gosan-ro 151beon-gil, Gunpo-si, 15853, Sout...  37.346181
#
#    Longtitude
# 0  127.103887
# 1  127.075418
# 2  126.964059
# 3  127.064230
# 4  126.956480

# %%
# plot the points of accountant office
acc_point = acc_office_df.hvplot.points(
    x = "Longtitude",
    y = "Latitude",
    geo = True,
    tiles = "OSM",
    color = 'Name',
    alpha = 0.8,
    frame_width = 700,
    frame_height = 500,
    size = 100,
    hover_cols = 'all'
)

acc_point
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longtitude,Latitude]   (Name,index,Address)
